# %% [markdown]
# # Netflix Movie Data
#
# This dataset contains more than 8,500 Netflix movies and TV shows, including cast members, duration, and genre. It contains titles added as recently as late September 2021.
#
# Not sure where to begin? Scroll to the bottom to find challenges!

# %%
import pandas as pd
import numpy as np
# !pip install rake-nltk
from rake_nltk import Rake
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Collecting nltk<4.0.0,>=3.6.2
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: joblib in c:\users\daniel\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (0.14.1)
# Collecting regex>=2021.8.3
#   Downloading regex-2023.6.3-cp37-cp37m-win_amd64.whl (268 kB)
# Requirement already satisfied: tqdm in c:\users\daniel\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.42.1)
# Requirement already satisfied: click in c:\users\daniel\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (7.0)
# Installing collected packages: regex, nltk, rake-nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.4.5
#     Uninstalling nltk-3.4.5:
#       Successfully uninstalled nltk-3.4.5
# Successfully installed nltk-3.8.1 rake-nltk-1.0.6 regex-2023.6.3

# %%
df = pd.read_csv('netflix_dataset.csv', index_col=0)
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %%
new = df[['title', 'description', 'listed_in','director','cast']]
new.head()
# Out:
#                          title  \
# show_id
# s1        Dick Johnson Is Dead
# s2               Blood & Water
# s3                   Ganglands
# s4       Jailbirds New Orleans
# s5                Kota Factory
#
#                                                description  \
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...
#
#                                                  listed_in         director  \
# show_id
# s1                                           Documentaries  Kirsten Johnson
# s2         International TV Shows, TV Dramas, TV Mysteries              NaN
# s3       Crime TV Shows, International TV Shows, TV Act...  Julien Leclercq
# s4                                  Docuseries, Reality TV              NaN
# s5       International TV Shows, Romantic TV Shows, TV ...              NaN
#
#                                                       cast
# show_id
# s1                                                     NaN
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s4                                                     NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...

# %%
new['cast'].astype(str)

new['listed_in'].astype(str)
            
new['director'].astype(str)
# Out:
# show_id
# s1       Kirsten Johnson
# s2                   nan
# s3       Julien Leclercq
# s4                   nan
# s5                   nan
#               ...
# s8803      David Fincher
# s8804                nan
# s8805    Ruben Fleischer
# s8806       Peter Hewitt
# s8807        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
new.dtypes
# Out:
# title          object
# description    object
# listed_in      object
# director       object
# cast           object
# dtype: object

# %%
new['cast'] = new['cast'].map(lambda x: x.split(',') [:])

new['listed_in'] = new['listed_in'].map(lambda x: x.split('') [:])

new['director'] = new['director'].map(lambda x: x.lower().split(' '))

for index, row in new.iterrows():
    row['cast'] = [actor.lower() for actor in row['cast']]
    row['listed_in'] = [genre.lower() for genre in row['listed_in']]
    row['director'] = ''.join(row['director']).lower()
new.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f48786bd1109> in <module>
# ----> 1 new['cast'] = new['cast'].map(lambda x: x.split(',') [:])
#       2
#       3 new['listed_in'] = new['listed_in'].map(lambda x: x.split('') [:])
#       4
#       5 new['director'] = new['director'].map(lambda x: x.lower().split(' '))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1152
#    1153         # mapper is a function
# -> 1154         new_values = map_f(values, mapper)
#    1155
#    1156         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-10-f48786bd1109> in <lambda>(x)
# ----> 1 new['cast'] = new['cast'].map(lambda x: x.split(',') [:])
#       2
#       3 new['listed_in'] = new['listed_in'].map(lambda x: x.split('') [:])
#       4
#       5 new['director'] = new['director'].map(lambda x: x.lower().split(' '))
#
# AttributeError: 'list' object has no attribute 'split'

# %%
import nltk
nltk.download("stopwords")
nltk.download("punkt")

from rake_nltk import Rake

r = Rake()

new['keywords'] = new['description'].apply(lambda x: r.extract_keywords_from_text(x))
new['keywords'] = new['description'].apply(lambda x: list(r.get_word_degrees().keys()))

new.head(10)
# Out:
# [nltk_data] Downloading package stopwords to /home/repl/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/repl/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                     title  ...                                           keywords
# show_id                                    ...
# s1                   Dick Johnson Is Dead  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s2                          Blood & Water  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s3                              Ganglands  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s4                  Jailbirds New Orleans  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s5                           Kota Factory  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s6                          Midnight Mass  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s7       My Little Pony: A New Generation  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s8                                Sankofa  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s9          The Great British Baking Show  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# s10                          The Starling  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
#
# [10 rows x 6 columns]

# %%
new.set_index('title', inplace = True)
new.drop(columns= ['description'], inplace= True)
new.head()
# Out:
#                                                                listed_in  ...                                           keywords
# title                                                                     ...
# Dick Johnson Is Dead             [d, o, c, u, m, e, n, t, a, r, i, e, s]  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# Blood & Water          [i, n, t, e, r, n, a, t, i, o, n, a, l,  , t, ...  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# Ganglands              [c, r, i, m, e,  , t, v,  , s, h, o, w, s, ,, ...  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# Jailbirds New Orleans  [d, o, c, u, s, e, r, i, e, s, ,,  , r, e, a, ...  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
# Kota Factory           [i, n, t, e, r, n, a, t, i, o, n, a, l,  , t, ...  ...  [scrappy, poor, boy, worms, way, tycoon, dysfu...
#
# [5 rows x 4 columns]

# %%
new['bag_of_words'] = ''
columns = new.columns
for index, row in new.iterrows():
    words = ''
    for col in columns:
        if col != 'director':
            words = words + ' '.join(str(row[col])) + ' '
        else:
            words = words + ' '.join(str(row[col])) + ' '
    new.at[index, 'bag_of_words'] = words

new.drop(columns=[col for col in new.columns if col != 'bag_of_words'], inplace=True)
new.head()
# Out:
#                                                             bag_of_words
# title
# Dick Johnson Is Dead   [ ' d ' ,   ' o ' ,   ' c ' ,   ' u ' ,   ' m ...
# Blood & Water          [ ' i ' ,   ' n ' ,   ' t ' ,   ' e ' ,   ' r ...
# Ganglands              [ ' c ' ,   ' r ' ,   ' i ' ,   ' m ' ,   ' e ...
# Jailbirds New Orleans  [ ' d ' ,   ' o ' ,   ' c ' ,   ' u ' ,   ' s ...
# Kota Factory           [ ' i ' ,   ' n ' ,   ' t ' ,   ' e ' ,   ' r ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')  # Add stop_words parameter

count_matrix = count.fit_transform(new['bag_of_words'])

indices = pd.Series(new.index)  # Change df to new
indices[:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 6>()
#       2 from sklearn.feature_extraction.text import CountVectorizer
#       4 count = CountVectorizer(stop_words='english')  # Add stop_words parameter
# ----> 6 count_matrix = count.fit_transform(new['bag_of_words'])
#       8 indices = pd.Series(new.index)  # Change df to new
#       9 indices[:5]
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py:1338, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1330             warnings.warn(
#    1331                 "Upper case characters found in"
#    1332                 " vocabulary while 'lowercase'"
#    1333                 " is True. These entries will not"
#    1334                 " be matched with any documents"
#    1335             )
#    1336             break
# -> 1338 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1340 if self.binary:
#    1341     X.data.fill(1)
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py:1228, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1226     vocabulary = dict(vocabulary)
#    1227     if not vocabulary:
# -> 1228         raise ValueError(
#    1229             "empty vocabulary; perhaps the documents only contain stop words"
#    1230         )
#    1232 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1233     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
cosine_sim= cosine_similarity(count_matrix, count_matrix)
cosine_sim

# %%
def recommendations(title, cosine_sim = cosine_sim):
    
    recommended_movies = []
    
    idx= indices[indices == title].index[1]
    
    score_series= pd.Series(cosine_sim[idx]).sort_values(ascending = False)
    
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    for i in top_10_indexes:
        recommended_movies.append(list(df.index)[i])
        
    return recommended_movies

# %%
def recommendations(title, cosine_sim=cosine_sim):
    recommended_movies = []
    
    # Find the index of the movie title in the indices list
    idx = indices[indices == title].index[0]
    
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending=False)
    
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # Get the titles of the recommended movies using the indices
    for i in top_10_indexes:
        recommended_movies.append(indices[i])
        
    return recommended_movies

recommendations('Zoom')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [33], in <cell line: 17>()
#      13         recommended_movies.append(indices[i])
#      15     return recommended_movies
# ---> 17 recommendations('Zoom')
#
# Input In [33], in recommendations(title, cosine_sim)
#       2 recommended_movies = []
#       4 # Find the index of the movie title in the indices list
# ----> 5 idx = indices[indices == title].index[0]
#       7 score_series = pd.Series(cosine_sim[idx]).sort_values(ascending=False)
#       9 top_10_indexes = list(score_series.iloc[1:11].index)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:5361, in Index.__getitem__(self, key)
#    5358 if is_integer(key) or is_float(key):
#    5359     # GH#44051 exclude bool, which would return a 2d ndarray
#    5360     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5361     return getitem(key)
#    5363 if isinstance(key, slice):
#    5364     # This case is separated from the conditional above to avoid
#    5365     # pessimization com.is_bool_indexer and ndim checks.
#    5366     result = getitem(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# [Source](https://www.kaggle.com/shivamb/netflix-shows) of dataset.

# %% [markdown]
# ## Don't know where to start?
#
# **Challenges are brief tasks designed to help you practice specific skills:**
#
# - 🗺️ **Explore**: How much variety exists in Netflix's offering? Base this on three variables: `type`, `country`, and `listed_in`.
# - 📊 **Visualize**: Build a word cloud from the movie and TV shows descriptions. Make sure to remove stop words!
# - 🔎 **Analyze**: Has Netflix invested more in certain genres (see `listed_in`) in recent years? What about certain age groups (see `ratings`)?
#
# **Scenarios are broader questions to help you develop an end-to-end project for your portfolio:**
#
# A talent agency has hired you to analyze patterns in the professional relationships of cast members and directors. The key deliverable is a network graph where each node represents a cast member or director. An edge represents a movie or TV show worked on by both nodes in this undirected graph. You can limit the actors to the first four names listed in `cast`. The client is interested in any insights you can derive from your Netflix network analysis, such as actor/actor and actor/director pairs that work most closely together, most popular actors and directors to work with, and graph differences over time.
#
# You will need to prepare a report that is accessible to a broad audience. It will need to outline your motivation, analysis steps, findings, and conclusions.
